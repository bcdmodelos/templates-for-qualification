# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdmodelos/qualificacao-modelscode/blob/main/Modelo-Computacional/codigo_modelo_prophet_paraiba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de Regressão pelo Prophet do Dados de COVID-19 para a Paraíba

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
from prophet.plot import add_changepoints_to_plot

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive/Notebooks_Doutorado/base-campina/

# !ls
# Out:
# /content/drive/MyDrive/Notebooks_Doutorado/base-campina
# dataset_Amazonas_usableData.csv
# dataset_Bodocongo_usable.csv
# dataset_Brasil_usableData.csv
# dataset_CampinaGrande_casos_acumulados_usable.csv
# dataset_CampinaGrande_casos_diarios_usable.csv
# dataset_CampinaGrande_usableData.csv
# dataset_Catole_usable.csv
# dataset_Malvinas_usable.csv
# dataset_Paraiba_usableData.csv
# dataset_Pernambuco_usableData.csv
# dfBrasil.csv
# dfBrasilProphet.csv
# dfParaibaProphet.csv

# %%
file_path = "./dfParaibaProphet.csv"
dfCasosParaiba = pd.read_csv(file_path, encoding='latin1')
dfCasosParaiba.head()
# Out:
#            ds  y
# 0  2020-03-22  1
# 1  2020-03-23  2
# 2  2020-03-24  3
# 3  2020-03-25  5
# 4  2020-03-26  6

# %%
dfCasosParaiba.set_index('ds').plot();

# %%
m = Prophet()
m = m.fit(dfCasosParaiba)
future = m.make_future_dataframe(periods=366)
forecast = m.predict(future)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpvczswwtl/t5h1vuz5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpvczswwtl/xmkw5ewp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73791', 'data', 'file=/tmp/tmpvczswwtl/t5h1vuz5.json', 'init=/tmp/tmpvczswwtl/xmkw5ewp.json', 'output', 'file=/tmp/tmpvczswwtl/prophet_model0vc6mw06/prophet_model-20221019030343.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:03:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:03:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
m.plot(forecast)
plt.axhline(y=0, color='red')

# %%
m.plot_components(forecast);
