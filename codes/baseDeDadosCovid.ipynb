# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdmodelos/qualificacao-modelscode/blob/main/CodigosAnalises/baseDeDadosCovid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise da Base de dados COVID-19

# %% [markdown]
# Base de Dados da COVID-19 no Brasil

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv")
df['date'] = pd.to_datetime(df['date'])
print(df.columns)

data_BR = df.query("state == 'TOTAL'")[['date', 'totalCases', 'deaths', 'suspects', 'recovered', 'tests', 'vaccinated', 'vaccinated_second']]
data_BR['activeCases'] = data_BR['totalCases'] - data_BR['deaths'] - data_BR['recovered']
data_BR['newVaccinated'] = data_BR['vaccinated'].diff()
data_BR['newVaccinated_second'] = data_BR['vaccinated_second'].diff()

data_BR
# Out:
# Index(['epi_week', 'date', 'country', 'state', 'city', 'newDeaths', 'deaths',
#        'newCases', 'totalCases', 'deathsMS', 'totalCasesMS',
#        'deaths_per_100k_inhabitants', 'totalCases_per_100k_inhabitants',
#        'deaths_by_totalCases', 'recovered', 'suspects', 'tests',
#        'tests_per_100k_inhabitants', 'vaccinated',
#        'vaccinated_per_100_inhabitants', 'vaccinated_second',
#        'vaccinated_second_per_100_inhabitants', 'vaccinated_single',
#        'vaccinated_single_per_100_inhabitants', 'vaccinated_third',
#        'vaccinated_third_per_100_inhabitants'],
#       dtype='object')
#             date  totalCases  deaths   suspects   recovered       tests  \
# 1     2020-02-25           1       0        NaN         NaN         NaN
# 3     2020-02-26           1       0        NaN         NaN         NaN
# 5     2020-02-27           1       0        NaN         NaN         NaN
# 7     2020-02-28           2       0        NaN         NaN         NaN
# ...

# %%
from google.colab import files
data_BR.to_csv('dataset_Brasil.csv')
files.download('dataset_Brasil.csv')

# %%
data_BR.plot(x="date", y="deaths",xlabel="Data",ylabel="Número de Mortos",label="Número Total de Mortos do Brasil")

# %%
data_BR.plot(x="date", y="totalCases",xlabel="Data",ylabel="Número de Casos (em milhões)",label="Número Total de Casos do Brasil")

# %% [markdown]
# **Base de Dados da COVID-19 na Paraíba**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv")
df['date'] = pd.to_datetime(df['date'])
print(df.columns)

data_PB = df.query("state == 'PB'")[['date', 'totalCases', 'deaths', 'suspects', 'recovered', 'tests', 'vaccinated', 'vaccinated_second']]
data_PB['activeCases'] = data_PB['totalCases'] - data_PB['deaths'] - data_PB['recovered']
data_PB['newVaccinated'] = data_PB['vaccinated'].diff()
data_PB['newVaccinated_second'] = data_PB['vaccinated_second'].diff()

data_PB
# Out:
# Index(['epi_week', 'date', 'country', 'state', 'city', 'newDeaths', 'deaths',
#        'newCases', 'totalCases', 'deathsMS', 'totalCasesMS',
#        'deaths_per_100k_inhabitants', 'totalCases_per_100k_inhabitants',
#        'deaths_by_totalCases', 'recovered', 'suspects', 'tests',
#        'tests_per_100k_inhabitants', 'vaccinated',
#        'vaccinated_per_100_inhabitants', 'vaccinated_second',
#        'vaccinated_second_per_100_inhabitants', 'vaccinated_single',
#        'vaccinated_single_per_100_inhabitants', 'vaccinated_third',
#        'vaccinated_third_per_100_inhabitants'],
#       dtype='object')
#             date  totalCases  deaths  suspects  recovered      tests  \
# 177   2020-03-18           1       0       NaN        NaN        NaN
# 199   2020-03-19           1       0       NaN        NaN        NaN
# 225   2020-03-20           1       0       NaN        NaN        NaN
# 252   2020-03-21           1       0       NaN        NaN        NaN
# ...

# %%
from google.colab import files
data_PB.to_csv('dataset_Paraíba.csv')
files.download('dataset_Paraíba.csv')

# %%
data_PB.plot(x="date", y="deaths",xlabel="Data",ylabel="Número de Mortos",label="Número Total de Mortos da Paraíba")

# %%
data_PB.plot(x="date", y="totalCases",xlabel="Data",ylabel="Número de Casos",label="Número Total de Casos da Paraíba")

# %% [markdown]
# Base de Dados da COVID-19 no Amazonas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv")
df['date'] = pd.to_datetime(df['date'])
print(df.columns)

data_AM = df.query("state == 'AM'")[['date', 'totalCases', 'deaths', 'suspects', 'recovered', 'tests', 'vaccinated', 'vaccinated_second']]
data_AM['activeCases'] = data_AM['totalCases'] - data_AM['deaths'] - data_AM['recovered']
data_AM['newVaccinated'] = data_AM['vaccinated'].diff()
data_AM['newVaccinated_second'] = data_AM['vaccinated_second'].diff()

data_AM
# Out:
# Index(['epi_week', 'date', 'country', 'state', 'city', 'newDeaths', 'deaths',
#        'newCases', 'totalCases', 'deathsMS', 'totalCasesMS',
#        'deaths_per_100k_inhabitants', 'totalCases_per_100k_inhabitants',
#        'deaths_by_totalCases', 'recovered', 'suspects', 'tests',
#        'tests_per_100k_inhabitants', 'vaccinated',
#        'vaccinated_per_100_inhabitants', 'vaccinated_second',
#        'vaccinated_second_per_100_inhabitants', 'vaccinated_single',
#        'vaccinated_single_per_100_inhabitants', 'vaccinated_third',
#        'vaccinated_third_per_100_inhabitants'],
#       dtype='object')
#             date  totalCases  deaths  suspects  recovered      tests  \
# 81    2020-03-13           2       0       NaN        NaN        NaN
# 96    2020-03-14           2       0       NaN        NaN        NaN
# 113   2020-03-15           2       0       NaN        NaN        NaN
# 130   2020-03-16           2       0       NaN        NaN        NaN
# ...

# %%
data_AM.plot(x="date", y="deaths",xlabel="Data",ylabel="Número de Mortos",label="Número Total de Mortos do Amazonas")

# %%
data_AM.plot(x="date", y="totalCases",xlabel="Data",ylabel="Número de Casos",label="Número Total de Casos do Amazonas")

# %% [markdown]
# Base de Dados da COVID-19 no Pernambuco

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv")
df['date'] = pd.to_datetime(df['date'])
print(df.columns)

data_PE = df.query("state == 'PE'")[['date', 'totalCases', 'deaths', 'suspects', 'recovered', 'tests', 'vaccinated', 'vaccinated_second']]
data_PE['activeCases'] = data_PE['totalCases'] - data_PE['deaths'] - data_PE['recovered']
data_PE['newVaccinated'] = data_PE['vaccinated'].diff()
data_PE['newVaccinated_second'] = data_PE['vaccinated_second'].diff()

data_PE
# Out:
# Index(['epi_week', 'date', 'country', 'state', 'city', 'newDeaths', 'deaths',
#        'newCases', 'totalCases', 'deathsMS', 'totalCasesMS',
#        'deaths_per_100k_inhabitants', 'totalCases_per_100k_inhabitants',
#        'deaths_by_totalCases', 'recovered', 'suspects', 'tests',
#        'tests_per_100k_inhabitants', 'vaccinated',
#        'vaccinated_per_100_inhabitants', 'vaccinated_second',
#        'vaccinated_second_per_100_inhabitants', 'vaccinated_single',
#        'vaccinated_single_per_100_inhabitants', 'vaccinated_third',
#        'vaccinated_third_per_100_inhabitants'],
#       dtype='object')
#             date  totalCases  deaths  suspects  recovered      tests  \
# 72    2020-03-12           2       0       NaN        NaN        NaN
# 87    2020-03-13           2       0       NaN        NaN        NaN
# 103   2020-03-14           7       0       NaN        NaN        NaN
# 120   2020-03-15           8       0       NaN        NaN        NaN
# ...

# %%
data_PE.plot(x="date", y="deaths",xlabel="Data",ylabel="Número de Mortos",label="Número Total de Mortos de Pernambuco")

# %%
data_PE.plot(x="date", y="totalCases",xlabel="Data",ylabel="Número de Casos",label="Número Total de Casos de Pernambuco")
